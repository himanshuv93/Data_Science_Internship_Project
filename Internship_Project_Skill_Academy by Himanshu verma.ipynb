# %% [markdown]
# Name: Hiamsnhu Verma
# Batch= 5
# Project= Internship Project
# course Data Science with python

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the TSV file into a Pandas DataFrame
df_tsv = pd.read_csv('C:\\Users\\Himanshu\\Desktop\\Datasets\\Order.tsv', sep='\t')
df_tsv.head()
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039     1-1-13        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313     1-3-13    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300     1-4-13  Devin Huddleston     Valence          France
# 3  BN-2011-2819714     1-4-13       Mary Parker  Birmingham  United Kingdom
# 4   AZ-2011-617423     1-5-13      Daniel Burke  Echirolles          France
#
#     Region      Segment Ship Date     Ship Mode                 State  \
# 0    North  Home Office    1-5-13  Economy Plus             Stockholm
# 1    North     Consumer    1-7-13       Economy               England
# 2  Central     Consumer    1-8-13       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate    1-9-13       Economy               England
# 4  Central  Home Office    1-7-13      Priority  Auvergne-Rhône-Alpes
#
#    Days to Ship
# 0             4
# 1             4
# 2             4
# 3             5
# ...

# %%
# Open the JSON file in read mode
with open("C:\\Users\\Himanshu\\Desktop\\Datasets\\Order_breakdown.json", 'r') as f:

    # Call the read() method on the file object
    data = json.load(f)
    
print(data)
# Out:
# [{'Order ID': 'BN-2011-7407039', 'Product Name': 'Enermax Note Cards, Premium', 'Discount': 0.5, 'Actual Discount': 22.5, 'Sales': 45, 'Profit': -26, 'Quantity': 3, 'Category': 'Office Supplies', 'Sub-Category': 'Paper'}, {'Order ID': 'AZ-2011-9050313', 'Product Name': 'Dania Corner Shelving, Traditional', 'Discount': 0, 'Actual Discount': 0, 'Sales': 854, 'Profit': 290, 'Quantity': 7, 'Category': 'Furniture', 'Sub-Category': 'Bookcases'}, {'Order ID': 'AZ-2011-6674300', 'Product Name': 'Binney & Smith Sketch Pad, Easy-Erase', 'Discount': 0, 'Actual Discount': 0, 'Sales': 140, 'Profit': 21, 'Quantity': 3, 'Category': 'Office Supplies', 'Sub-Category': 'Art'}, {'Order ID': 'BN-2011-2819714', 'Product Name': 'Boston Markers, Easy-Erase', 'Discount': 0.5, 'Actual Discount': 13.5, 'Sales': 27, 'Profit': -22, 'Quantity': 2, 'Category': 'Office Supplies', 'Sub-Category': 'Art'}, {'Order ID': 'BN-2011-2819714', 'Product Name': 'Eldon Folders, Single Width', 'Discount': 0.5, 'Actual Discount
# ...

# %%
df_json=pd.DataFrame(data)

# %%
df_json.head()
# Out:
#           Order ID                           Product Name  Discount  \
# 0  BN-2011-7407039            Enermax Note Cards, Premium       0.5
# 1  AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0
# 2  AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0
# 3  BN-2011-2819714             Boston Markers, Easy-Erase       0.5
# 4  BN-2011-2819714            Eldon Folders, Single Width       0.5
#
#    Actual Discount  Sales  Profit  Quantity         Category Sub-Category
# 0             22.5     45     -26         3  Office Supplies        Paper
# 1              0.0    854     290         7        Furniture    Bookcases
# 2              0.0    140      21         3  Office Supplies          Art
# 3             13.5     27     -22         2  Office Supplies          Art
# 4              8.5     17      -1         2  Office Supplies      Storage

# %%
df_tsv.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'City', 'Country', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Days to Ship'],
#       dtype='object')

# %%
df_json.columns
# Out:
# Index(['Order ID', 'Product Name', 'Discount', 'Actual Discount', 'Sales',
#        'Profit', 'Quantity', 'Category', 'Sub-Category'],
#       dtype='object')

# %%
df = df_tsv.merge(df_json, on='Order ID')

# %%
df.head()
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039     1-1-13        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313     1-3-13    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300     1-4-13  Devin Huddleston     Valence          France
# 3  BN-2011-2819714     1-4-13       Mary Parker  Birmingham  United Kingdom
# 4  BN-2011-2819714     1-4-13       Mary Parker  Birmingham  United Kingdom
#
#     Region      Segment Ship Date     Ship Mode                 State  \
# 0    North  Home Office    1-5-13  Economy Plus             Stockholm
# 1    North     Consumer    1-7-13       Economy               England
# 2  Central     Consumer    1-8-13       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate    1-9-13       Economy               England
# 4    North    Corporate    1-9-13       Economy               England
#
#    Days to Ship                           Product Name  Discount  \
# ...

# %%
df.shape
# Out:
# (8047, 19)

# %%
df.isnull().sum()
# Out:
# Order ID           0
# Order Date         0
# Customer Name      0
# City               0
# Country            0
# Region             0
# Segment            0
# Ship Date          0
# Ship Mode          0
# State              0
# Days to Ship       0
# Product Name       0
# Discount           0
# Actual Discount    0
# Sales              0
# Profit             0
# Quantity           0
# Category           0
# Sub-Category       0
# dtype: int64

# %%
df.to_csv('Amazing_Mart_data.csv')

# %%
df_am=pd.read_csv('Amazing_Mart_data.csv')
df_am.head()
# Out:
#    Unnamed: 0         Order ID Order Date     Customer Name        City  \
# 0           0  BN-2011-7407039     1-1-13        Ruby Patel   Stockholm
# 1           1  AZ-2011-9050313     1-3-13    Summer Hayward   Southport
# 2           2  AZ-2011-6674300     1-4-13  Devin Huddleston     Valence
# 3           3  BN-2011-2819714     1-4-13       Mary Parker  Birmingham
# 4           4  BN-2011-2819714     1-4-13       Mary Parker  Birmingham
#
#           Country   Region      Segment Ship Date     Ship Mode  \
# 0          Sweden    North  Home Office    1-5-13  Economy Plus
# 1  United Kingdom    North     Consumer    1-7-13       Economy
# 2          France  Central     Consumer    1-8-13       Economy
# 3  United Kingdom    North    Corporate    1-9-13       Economy
# 4  United Kingdom    North    Corporate    1-9-13       Economy
#
#                   State  Days to Ship                           Product Name  \
# ...

# %%
df_am.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df_am.head()
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039     1-1-13        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313     1-3-13    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300     1-4-13  Devin Huddleston     Valence          France
# 3  BN-2011-2819714     1-4-13       Mary Parker  Birmingham  United Kingdom
# 4  BN-2011-2819714     1-4-13       Mary Parker  Birmingham  United Kingdom
#
#     Region      Segment Ship Date     Ship Mode                 State  \
# 0    North  Home Office    1-5-13  Economy Plus             Stockholm
# 1    North     Consumer    1-7-13       Economy               England
# 2  Central     Consumer    1-8-13       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate    1-9-13       Economy               England
# 4    North    Corporate    1-9-13       Economy               England
#
#    Days to Ship                           Product Name  Discount  \
# ...

# %%
df_am.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order ID         8047 non-null   object
#  1   Order Date       8047 non-null   object
#  2   Customer Name    8047 non-null   object
#  3   City             8047 non-null   object
#  4   Country          8047 non-null   object
#  5   Region           8047 non-null   object
#  6   Segment          8047 non-null   object
#  7   Ship Date        8047 non-null   object
#  8   Ship Mode        8047 non-null   object
#  9   State            8047 non-null   object
#  10  Days to Ship     8047 non-null   int64
#  11  Product Name     8047 non-null   object
#  12  Discount         8047 non-null   float64
#  13  Actual Discount  8047 non-null   float64
#  14  Sales            8047 non-null   int64
#  15  Profit           8047 non-null   int64
# ...

# %%
df_am.duplicated().sum()
# Out:
# 2

# %%
df_am=df_am.drop_duplicates()

# %%
df_am.duplicated().sum()
# Out:
# 0

# %%
# converting object data type to date time for order date and ship date 
df_am['Order Date'] = pd.to_datetime(df_am['Order Date'])
df_am['Ship Date'] = pd.to_datetime(df_am['Ship Date'])

# %%
df_am.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8045 entries, 0 to 8046
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order ID         8045 non-null   object
#  1   Order Date       8045 non-null   datetime64[ns]
#  2   Customer Name    8045 non-null   object
#  3   City             8045 non-null   object
#  4   Country          8045 non-null   object
#  5   Region           8045 non-null   object
#  6   Segment          8045 non-null   object
#  7   Ship Date        8045 non-null   datetime64[ns]
#  8   Ship Mode        8045 non-null   object
#  9   State            8045 non-null   object
#  10  Days to Ship     8045 non-null   int64
#  11  Product Name     8045 non-null   object
#  12  Discount         8045 non-null   float64
#  13  Actual Discount  8045 non-null   float64
#  14  Sales            8045 non-null   int64
#  15  Profit           8045 non-null   int64
# ...

# %%
df_am.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'City', 'Country', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Days to Ship',
#        'Product Name', 'Discount', 'Actual Discount', 'Sales', 'Profit',
#        'Quantity', 'Category', 'Sub-Category'],
#       dtype='object')

# %%
df_am['City'].value_counts()
# Out:
# London                219
# Vienna                196
# Berlin                177
# Madrid                149
# Stockholm             124
#                      ...
# Cercola                 1
# Fareham                 1
# Tremblay-en-France      1
# Guimarães               1
# Sagunto                 1
# Name: City, Length: 999, dtype: int64

# %%
df_am['Country'].value_counts()
# Out:
# France            1916
# Germany           1640
# United Kingdom    1314
# Italy              979
# Spain              760
# Netherlands        393
# Austria            264
# Sweden             203
# Belgium            134
# Ireland            100
# Switzerland         78
# Norway              70
# Portugal            70
# Finland             64
# Denmark             60
# Name: Country, dtype: int64

# %%
df_am['Region'].value_counts()
# Out:
# Central    4425
# North      1811
# South      1809
# Name: Region, dtype: int64

# %%
df_am['Segment'].value_counts()
# Out:
# Consumer       4173
# Corporate      2514
# Home Office    1358
# Name: Segment, dtype: int64

# %%
df_am['Ship Mode'].value_counts()
# Out:
# Economy         4860
# Economy Plus    1590
# Priority        1169
# Immediate        426
# Name: Ship Mode, dtype: int64

# %%
df_am['State'].value_counts()
# Out:
# England                       1187
# Ile-de-France                  673
# North Rhine-Westphalia         572
# Provence-Alpes-Côte d'Azur     250
# Madrid                         198
#                               ...
# Södermanland                     1
# Zeeland                          1
# Aveiro                           1
# Extremadura                      1
# Setúbal                          1
# Name: State, Length: 127, dtype: int64

# %%
df_am['Quantity'].value_counts()
# Out:
# 3     1978
# 2     1971
# 4     1000
# 5      938
# 1      681
# 6      474
# 7      468
# 8      206
# 9      180
# 11      44
# 10      43
# 12      26
# 14      19
# 13      17
# Name: Quantity, dtype: int64

# %%
df_am['Category'].value_counts()
# Out:
# Office Supplies    5284
# Technology         1523
# Furniture          1238
# Name: Category, dtype: int64

# %%
df_am['Sub-Category'].value_counts()
# Out:
# Art            1151
# Binders        1058
# Storage        1051
# Phones          453
# Bookcases       391
# Furnishings     389
# Chairs          383
# Paper           374
# Labels          372
# Accessories     368
# Copiers         367
# Fasteners       350
# Supplies        347
# Envelopes       346
# Machines        335
# Appliances      235
# Tables           75
# Name: Sub-Category, dtype: int64

# %%
df_cs=df_am.groupby('Country')['Sales'].sum()
df_cs
# Out:
# Country
# Austria            79382
# Belgium            42283
# Denmark             7763
# Finland            20702
# France            609683
# Germany           488681
# Ireland            15998
# Italy             252742
# Netherlands        70313
# Norway             20529
# Portugal           15106
# Spain             249318
# Sweden             30490
# Switzerland        24874
# United Kingdom    420497
# Name: Sales, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.barplot(x=df_cs.index,y=df_cs.values)
plt.title('sales compared with Country',color='black',fontsize=25,fontweight='bold',fontfamily='serif')
plt.xlabel('Countries',color='black',fontsize=15,fontweight='bold',fontfamily='serif')
plt.ylabel('sales',color='black',fontsize=15,fontweight='bold',fontfamily='serif')
plt.xticks(rotation=90)
plt.show()

# %%
df_cp=df_am.groupby('Country')['Profit'].sum()
df_cp
# Out:
# Country
# Austria           21332
# Belgium            9902
# Denmark           -3608
# Finland            3908
# France            70067
# Germany           86279
# Ireland           -6886
# Italy             15802
# Netherlands      -37188
# Norway             5167
# Portugal          -8704
# Spain             47039
# Sweden           -17524
# Switzerland        7234
# United Kingdom    90382
# Name: Profit, dtype: int64

# %%
plt.bar(df_cp.index,df_cp.values, color='blue',edgecolor='black')
plt.title('Sum of Profit in Different Countries',size=15)
plt.xlabel('Country')
plt.ylabel('Sum of Profit')
plt.xticks(rotation=90)
plt.show()

# %%
df_am['year'] = df_am['Order Date'].dt.year

# %%
df_so=df_am.groupby('year')['Profit'].sum()
df_so
# Out:
# year
# 2013    54487
# 2014    66058
# 2015    77035
# 2016    85622
# Name: Profit, dtype: int64

# %%
df_am.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'City', 'Country', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Days to Ship',
#        'Product Name', 'Discount', 'Actual Discount', 'Sales', 'Profit',
#        'Quantity', 'Category', 'Sub-Category', 'year'],
#       dtype='object')

# %%
df_am.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'City', 'Country', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Days to Ship',
#        'Product Name', 'Discount', 'Actual Discount', 'Sales', 'Profit',
#        'Quantity', 'Category', 'Sub-Category', 'year'],
#       dtype='object')

# %%
plt.figure(figsize=(8,4))
sns.barplot(x=df_so.index,y=df_so.values)
plt.title('Sales compared with year',color='black',fontsize=25,fontweight='bold',fontfamily='serif')
plt.xlabel('Years',color='black',fontsize=15,fontweight='bold',fontfamily='serif')
plt.ylabel('Sales',color='black',fontsize=15,fontweight='bold',fontfamily='serif')
plt.xticks(rotation=90)
plt.show()

# %%
df_sms=df_am.groupby('Ship Mode')['Sales'].sum()
df_sms
# Out:
# Ship Mode
# Economy         1412656
# Economy Plus     483965
# Immediate        131314
# Priority         320426
# Name: Sales, dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.barplot(x=df_sms.index,y=df_sms.values)
plt.title('Sales compared with Ship mode',color='black',fontsize=25,fontweight='bold',fontfamily='serif')
plt.xlabel('Ship Mode',color='black',fontsize=15,fontweight='bold',fontfamily='serif')
plt.ylabel('Sales',color='black',fontsize=15,fontweight='bold',fontfamily='serif')
plt.xticks(rotation=90)
plt.show()

# %%
df_am.describe()
# Out:
#        Days to Ship     Discount  Actual Discount        Sales       Profit  \
# count   8045.000000  8045.000000      8045.000000  8045.000000  8045.000000
# mean       4.006588     0.110075        29.800485   291.903170    35.202237
# std        1.740808     0.181787        88.827454   485.258616   178.147747
# min        0.000000     0.000000         0.000000     3.000000 -3060.000000
# 25%        3.000000     0.000000         0.000000    48.000000     1.000000
# 50%        4.000000     0.000000         0.000000   117.000000    14.000000
# 75%        5.000000     0.100000        22.000000   313.000000    47.000000
# max        7.000000     0.850000      1700.000000  6517.000000  2476.000000
#
#           Quantity         year
# count  8045.000000  8045.000000
# mean      3.772281  2014.731137
# std       2.203610     1.100577
# min       1.000000  2013.000000
# 25%       2.000000  2014.000000
# 50%       3.000000  2015.000000
# 75%       5.000000  2016.000000
# ...

# %%
corr=df_am.corr()
corr
# Out:
#                  Days to Ship  Discount  Actual Discount     Sales    Profit  \
# Days to Ship         1.000000  0.017547        -0.018932 -0.004393  0.014172
# Discount             0.017547  1.000000         0.426090 -0.026424 -0.351359
# Actual Discount     -0.018932  0.426090         1.000000  0.478885 -0.395889
# Sales               -0.004393 -0.026424         0.478885  1.000000  0.441218
# Profit               0.014172 -0.351359        -0.395889  0.441218  1.000000
# Quantity             0.001623  0.003633         0.207130  0.353415  0.098664
# year                -0.002060  0.019381        -0.000244  0.003289 -0.008412
#
#                  Quantity      year
# Days to Ship     0.001623 -0.002060
# Discount         0.003633  0.019381
# Actual Discount  0.207130 -0.000244
# Sales            0.353415  0.003289
# Profit           0.098664 -0.008412
# Quantity         1.000000 -0.000439
# year            -0.000439  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.show()

# %%
df_am.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'City', 'Country', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Days to Ship',
#        'Product Name', 'Discount', 'Actual Discount', 'Sales', 'Profit',
#        'Quantity', 'Category', 'Sub-Category', 'year'],
#       dtype='object')

# %% [markdown]
# ### Dropping the irrelevant columns related to the columns

# %%
df_am.drop(columns=['Order ID', 'Customer Name','Order Date','Ship Date'], axis=1,inplace=True)

# %%
df_am.columns
# Out:
# Index(['City', 'Country', 'Region', 'Segment', 'Ship Mode', 'State',
#        'Days to Ship', 'Product Name', 'Discount', 'Actual Discount', 'Sales',
#        'Profit', 'Quantity', 'Category', 'Sub-Category', 'year'],
#       dtype='object')

# %%
df_am.shape
# Out:
# (8045, 16)

# %%
df_am.shape
# Out:
# (8045, 16)

# %%
df_am.head()
# Out:
#          City         Country   Region      Segment     Ship Mode  \
# 0   Stockholm          Sweden    North  Home Office  Economy Plus
# 1   Southport  United Kingdom    North     Consumer       Economy
# 2     Valence          France  Central     Consumer       Economy
# 3  Birmingham  United Kingdom    North    Corporate       Economy
# 4  Birmingham  United Kingdom    North    Corporate       Economy
#
#                   State  Days to Ship                           Product Name  \
# 0             Stockholm             4            Enermax Note Cards, Premium
# 1               England             4     Dania Corner Shelving, Traditional
# 2  Auvergne-Rhône-Alpes             4  Binney & Smith Sketch Pad, Easy-Erase
# 3               England             5             Boston Markers, Easy-Erase
# 4               England             5            Eldon Folders, Single Width
#
#    Discount  Actual Discount  Sales  Profit  Quantity         Category  \
# ...

# %% [markdown]
# ### Importing necessary libraries to build our model

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor

# %%
res = {'Model':[],'R2Score':[]}

def eval_model(model,ytest,ypred):
    r2s=r2_score(ytest,ypred)
    print('R2Score',r2s)
    
    res['Model'].append(model)
    res['R2Score'].append(r2s)

# %%
X=df_am.drop('Sales',axis=1)
y=df_am['Sales']

# %%
print(type(X))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print('Training data X',X_train.shape)
print('Training Data y',y_train.shape)
print('Test data X',X_test.shape)
print('Test data y',y_test.shape)
# Out:
# Training data X (6436, 15)
# Training Data y (6436,)
# Test data X (1609, 15)
# Test data y (1609,)

# %%
df_am.columns
# Out:
# Index(['City', 'Country', 'Region', 'Segment', 'Ship Mode', 'State',
#        'Days to Ship', 'Product Name', 'Discount', 'Actual Discount', 'Sales',
#        'Profit', 'Quantity', 'Category', 'Sub-Category', 'year'],
#       dtype='object')

# %%
df_am.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8045 entries, 0 to 8046
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             8045 non-null   object
#  1   Country          8045 non-null   object
#  2   Region           8045 non-null   object
#  3   Segment          8045 non-null   object
#  4   Ship Mode        8045 non-null   object
#  5   State            8045 non-null   object
#  6   Days to Ship     8045 non-null   int64
#  7   Product Name     8045 non-null   object
#  8   Discount         8045 non-null   float64
#  9   Actual Discount  8045 non-null   float64
#  10  Sales            8045 non-null   int64
#  11  Profit           8045 non-null   int64
#  12  Quantity         8045 non-null   int64
#  13  Category         8045 non-null   object
#  14  Sub-Category     8045 non-null   object
#  15  year             8045 non-null   int64
# dtypes: float64(2), int64(5), object(9)
# ...

# %% [markdown]
# ### One Hot Encodeing(ohe)

# %%
# Applying one hot encoding
ohe = OneHotEncoder()
ohe.fit(X[['City','Country','Region','Segment','Ship Mode','State','Product Name','Category','Sub-Category']])
# Out:
# OneHotEncoder()

# %%
column_trans = make_column_transformer((OneHotEncoder(categories=ohe.categories_),['City','Country','Region','Segment','Ship Mode','State','Product Name','Category','Sub-Category']),
                                       remainder='passthrough')

# %%
column_trans
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('onehotencoder',
#                                  OneHotEncoder(categories=[array(['Aachen', 'Aalen', 'Aalst', 'Abbeville', 'Aberdeen', 'Acerra',
#        'Acireale', 'Afragola', 'Agde', 'Agen', 'Agrigento',
#        'Aix-en-Provence', 'Aix-les-Bains', 'Ajaccio', 'Albacete',
#        'Albertville', 'Albi', 'Alcobendas', 'Alessandria', 'Alfortville',
#        'Alicante', 'Alkmaar', '...
#                                                            array(['Furniture', 'Office Supplies', 'Technology'], dtype=object),
#                                                            array(['Accessories', 'Appliances', 'Art', 'Binders', 'Bookcases',
#        'Chairs', 'Copiers', 'Envelopes', 'Fasteners', 'Furnishings',
#        'Labels', 'Machines', 'Paper', 'Phones', 'Storage', 'Supplies',
#        'Tables'], dtype=object)]),
#                                  ['City', 'Country', 'Region', 'Segment',
# ...

# %% [markdown]
# ### Building Regreesion Model

# %% [markdown]
# #### 1) Linear Regression model

# %%
lr = LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Aachen', 'Aalen', 'Aalst', 'Abbeville', 'Aberdeen', 'Acerra',
#        'Acireale', 'Afragola', 'Agde', 'Agen', 'Agrigento',
#        'Aix-en-Provence', 'Aix-les-Bains', 'Ajaccio', 'Albacete',
#        'Albertville', 'Albi', 'Alcobendas', 'Alessandria'...
#                                                                             array(['Furniture', 'Office Supplies', 'Technology'], dtype=object),
#                                                                             array(['Accessories', 'Appliances', 'Art', 'Binders', 'Bookcases',
#        'Chairs', 'Copiers', 'Envelopes', 'Fasteners', 'Furnishings',
#        'Labels', 'Machines', 'Paper', 'Phones', 'Storage', 'Supplies',
#        'Tables'], dtype=object)]),
# ...

# %%
y_pred_lr = pipe.predict(X_test)

# %%
r2_score(y_test,y_pred_lr)
# Out:
# 0.7923382483348831

# %%
eval_model(lr,y_test,y_pred_lr)
# Out:
# R2Score 0.7923382483348831

# %% [markdown]
# #### 2) Lasso Regression Model

# %%
las = Lasso()

# %%
pipe=make_pipeline(column_trans,las)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Aachen', 'Aalen', 'Aalst', 'Abbeville', 'Aberdeen', 'Acerra',
#        'Acireale', 'Afragola', 'Agde', 'Agen', 'Agrigento',
#        'Aix-en-Provence', 'Aix-les-Bains', 'Ajaccio', 'Albacete',
#        'Albertville', 'Albi', 'Alcobendas', 'Alessandria'...
#                                                                             array(['Furniture', 'Office Supplies', 'Technology'], dtype=object),
#                                                                             array(['Accessories', 'Appliances', 'Art', 'Binders', 'Bookcases',
#        'Chairs', 'Copiers', 'Envelopes', 'Fasteners', 'Furnishings',
#        'Labels', 'Machines', 'Paper', 'Phones', 'Storage', 'Supplies',
#        'Tables'], dtype=object)]),
# ...

# %%
y_pred_las = pipe.predict(X_test)

# %%
r2_score(y_test,y_pred_las)
# Out:
# 0.7621291476819114

# %%
eval_model(las,y_test,y_pred_las)
# Out:
# R2Score 0.7621291476819114

# %% [markdown]
# #### 3) Random Forest Model

# %%
rf = RandomForestRegressor(n_estimators=100, max_depth=10)

# %%
pipe=make_pipeline(column_trans,rf)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Aachen', 'Aalen', 'Aalst', 'Abbeville', 'Aberdeen', 'Acerra',
#        'Acireale', 'Afragola', 'Agde', 'Agen', 'Agrigento',
#        'Aix-en-Provence', 'Aix-les-Bains', 'Ajaccio', 'Albacete',
#        'Albertville', 'Albi', 'Alcobendas', 'Alessandria'...
#                                                                             array(['Accessories', 'Appliances', 'Art', 'Binders', 'Bookcases',
#        'Chairs', 'Copiers', 'Envelopes', 'Fasteners', 'Furnishings',
#        'Labels', 'Machines', 'Paper', 'Phones', 'Storage', 'Supplies',
#        'Tables'], dtype=object)]),
#                                                   ['City', 'Country', 'Region',
#                                                    'Segment', 'Ship Mode',
# ...

# %%
y_pred_rf = pipe.predict(X_test)

# %%
r2_score(y_test,y_pred_rf)
# Out:
# 0.825761838079579

# %%
eval_model(rf,y_test,y_pred_rf)
# Out:
# R2Score 0.825761838079579

# %% [markdown]
# #### 4) Applying Bagging on Random Forest model

# %%
from sklearn.ensemble import BaggingRegressor

# %%
bag_rf = BaggingRegressor(base_estimator=rf, n_estimators=10,random_state=42)

# %%
pipe=make_pipeline(column_trans,bag_rf)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Aachen', 'Aalen', 'Aalst', 'Abbeville', 'Aberdeen', 'Acerra',
#        'Acireale', 'Afragola', 'Agde', 'Agen', 'Agrigento',
#        'Aix-en-Provence', 'Aix-les-Bains', 'Ajaccio', 'Albacete',
#        'Albertville', 'Albi', 'Alcobendas', 'Alessandria'...
#                                                                             array(['Accessories', 'Appliances', 'Art', 'Binders', 'Bookcases',
#        'Chairs', 'Copiers', 'Envelopes', 'Fasteners', 'Furnishings',
#        'Labels', 'Machines', 'Paper', 'Phones', 'Storage', 'Supplies',
#        'Tables'], dtype=object)]),
#                                                   ['City', 'Country', 'Region',
#                                                    'Segment', 'Ship Mode',
# ...

# %%
y_pred_bag_rf = pipe.predict(X_test)

# %%
r2_score(y_test,y_pred_bag_rf)
# Out:
# 0.8183167201928438

# %%
eval_model(bag_rf,y_test,y_pred_bag_rf)
# Out:
# R2Score 0.8183167201928438

# %% [markdown]
# #### 4) Applying AdaBoost on Random Forest

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
boost_rf = AdaBoostRegressor(base_estimator=rf, n_estimators=10, learning_rate=0.1, random_state=42)

# %%
pipe=make_pipeline(column_trans,boost_rf)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Aachen', 'Aalen', 'Aalst', 'Abbeville', 'Aberdeen', 'Acerra',
#        'Acireale', 'Afragola', 'Agde', 'Agen', 'Agrigento',
#        'Aix-en-Provence', 'Aix-les-Bains', 'Ajaccio', 'Albacete',
#        'Albertville', 'Albi', 'Alcobendas', 'Alessandria'...
#        'Chairs', 'Copiers', 'Envelopes', 'Fasteners', 'Furnishings',
#        'Labels', 'Machines', 'Paper', 'Phones', 'Storage', 'Supplies',
#        'Tables'], dtype=object)]),
#                                                   ['City', 'Country', 'Region',
#                                                    'Segment', 'Ship Mode',
#                                                    'State', 'Product Name',
#                                                    'Category',
# ...

# %%
y_pred_boost_rf= pipe.predict(X_test)

# %%
r2_score(y_test,y_pred_boost_rf)
# Out:
# 0.8225644578573782

# %%
eval_model(boost_rf,y_test,y_pred_boost_rf)
# Out:
# R2Score 0.8225644578573782

# %% [markdown]
# ### 5) Building Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor(max_depth=5)

# %%
pipe=make_pipeline(column_trans,dt)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Aachen', 'Aalen', 'Aalst', 'Abbeville', 'Aberdeen', 'Acerra',
#        'Acireale', 'Afragola', 'Agde', 'Agen', 'Agrigento',
#        'Aix-en-Provence', 'Aix-les-Bains', 'Ajaccio', 'Albacete',
#        'Albertville', 'Albi', 'Alcobendas', 'Alessandria'...
#                                                                             array(['Accessories', 'Appliances', 'Art', 'Binders', 'Bookcases',
#        'Chairs', 'Copiers', 'Envelopes', 'Fasteners', 'Furnishings',
#        'Labels', 'Machines', 'Paper', 'Phones', 'Storage', 'Supplies',
#        'Tables'], dtype=object)]),
#                                                   ['City', 'Country', 'Region',
#                                                    'Segment', 'Ship Mode',
# ...

# %%
y_pred_dt = pipe.predict(X_test)

# %%
r2_score(y_test,y_pred_dt)
# Out:
# 0.7643483102373311

# %%
eval_model(boost_rf,y_test,y_pred_dt)
# Out:
# R2Score 0.7643483102373311

# %%
gbr = GradientBoostingRegressor()
pipe = make_pipeline(column_trans,gbr)
pipe.fit(X_train,y_train)
y_pred_gbr = pipe.predict(X_test)
r2_score(y_test,y_pred_gbr)
eval_model(gbr,y_test,y_pred_gbr)
# Out:
# R2Score 0.8220242339816932

# %%
etr = ExtraTreesRegressor()
pipe = make_pipeline(column_trans,etr)
pipe.fit(X_train,y_train)
y_pred_etr = pipe.predict(X_test)
r2_score(y_test,y_pred_etr)
eval_model(etr,y_test,y_pred_etr)
# Out:
# R2Score 0.8604971148553554

# %%
print(res)
# Out:
# {'Model': [LinearRegression(), Lasso(), RandomForestRegressor(max_depth=10), BaggingRegressor(base_estimator=RandomForestRegressor(max_depth=10),
#                  random_state=42), AdaBoostRegressor(base_estimator=RandomForestRegressor(max_depth=10),
#                   learning_rate=0.1, n_estimators=10, random_state=42), AdaBoostRegressor(base_estimator=RandomForestRegressor(max_depth=10),
#                   learning_rate=0.1, n_estimators=10, random_state=42), GradientBoostingRegressor(), ExtraTreesRegressor()], 'R2Score': [0.7923382483348831, 0.7621291476819114, 0.825761838079579, 0.8183167201928438, 0.8225644578573782, 0.7643483102373311, 0.8220242339816932, 0.8604971148553554]}

# %%
model_per=pd.DataFrame(res)
model_per
# Out:
#                                                Model   R2Score
# 0                                 LinearRegression()  0.792338
# 1                                            Lasso()  0.762129
# 2  (DecisionTreeRegressor(max_depth=10, max_featu...  0.825762
# 3  ((DecisionTreeRegressor(max_depth=10, max_feat...  0.818317
# 4  ((DecisionTreeRegressor(max_depth=10, max_feat...  0.822564
# 5  ((DecisionTreeRegressor(max_depth=10, max_feat...  0.764348
# 6  ([DecisionTreeRegressor(criterion='friedman_ms...  0.822024
# 7  (ExtraTreeRegressor(random_state=532279331), E...  0.860497

# %% [markdown]
# #### I am taking ExtraTreeRegressor model

# %%
import pickle

# %%
pickle.dump(pipe,open('AMSales.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Valence','France','Central','Consumer','Economy','Auvergne-Rhône-Alpes',4,'Binney & Smith Sketch Pad, Easy-Erase',0.0,0.0,21,3,'Office Supplies','Art',2013]],columns=['City', 'Country', 'Region', 'Segment', 'Ship Mode', 'State',
       'Days to Ship', 'Product Name', 'Discount', 'Actual Discount', 'Profit', 'Quantity', 'Category', 'Sub-Category', 'year']))
# Out:
# array([71.])

# %%
random_data = df_am.sample(n=20,random_state=42)

# %%
random_data.shape
# Out:
# (20, 16)

# %%
random_data.to_csv('Sample_data.csv')

# %%
random_data.head(2)
# Out:
#            City         Country Region    Segment Ship Mode    State  \
# 743   Harrogate  United Kingdom  North  Corporate   Economy  England
# 4883       Rome           Italy  South   Consumer   Economy    Lazio
#
#       Days to Ship                   Product Name  Discount  Actual Discount  \
# 743              5  Tenex File Cart, Single Width       0.0              0.0
# 4883             5        HP Fax Machine, Digital       0.0              0.0
#
#       Sales  Profit  Quantity         Category Sub-Category  year
# 743     268      24         2  Office Supplies      Storage  2013
# 4883   1498       0         5       Technology      Copiers  2015

# %%
x_new = random_data.drop('Sales',axis=1)
y_new = random_data['Sales']

# %%
import joblib

loded_model = joblib.load('AMSales.pkl')

# %%
y_pred1 = loded_model.predict(x_new)

# %%
comparision_df = pd.DataFrame({'Actual':y_new,'Predicted':y_pred1})

# %%
comparision_df
# Out:
#       Actual  Predicted
# 743      268     268.00
# 4883    1498    1498.00
# 4176      59      59.00
# 6942      11      11.00
# 3017      15      15.00
# 2945     106     139.30
# 6526     165     165.00
# 4742      43      42.35
# 4296      66     143.51
# 518       99      99.00
# 1383     185     185.00
# 1952     103     125.79
# 5493     596     596.00
# 1515     171     167.39
# 2354      15      15.00
# 2615     147     147.00
# 222      285     285.00
# 1454     284     284.00
# 5709     735     735.00
# 3214    1249     625.15

# %%
import pandas as pd
import numpy as np
import streamlit as st
import joblib
import pickle
import sklearn

# %%
print(pd.__version__)
print(np.__version__)
print(st.__version__)
print(joblib.__version__)
print(sklearn.__version__)
# Out:
# 1.4.4
# 1.21.5
# 1.23.1
# 1.2.0
# 1.0.2
